# %% [markdown]
# # Preparations

# %%
# Do something with Pkg...
import Pkg
Pkg.DEFAULT_IO[] = stdout;

# %%
using BenchmarkTools
using DifferentialEquations
using DiffEqBase
using DiffEqJump
using JSON
using LSODA
using ModelingToolkit
using OrdinaryDiffEq
using Plots
using ReactionNetworkImporters
using Sundials

# %%
# Serialises a benchmarking output using JSON.
function json_serialize(benchmarks,lengs,filename)
   open("../Benchmarking_results/Prototyping/$(filename).json","w") do f 
        medians = map(bm -> median(bm.times)/1000000, benchmarks)
        JSON.print(f, Dict("benchmarks"=>benchmarks, "medians"=>medians, "lengs"=>lengs))
    end 
end;

# %%
# Sets plotting defaults
default(framestyle=:box,grid=false,lw=4,la=0.8,guidefontsize=11,legend=:topleft)

# %%
using Catalyst
rn = @reaction_network begin
    p, 0 --> X
end p
ODEProblem(convert(ODESystem,rn),[1.0],(0.,10.0),[1.0],jac=false)
# Out:
# ODEProblem with uType Vector{Float64} and tType Float64. In-place: true
# timespan: (0.0, 10.0)
# u0: 1-element Vector{Float64}:
#  1.0

# %% [markdown]
# # Analysis

# %% [markdown]
# ### Multistate

# %%
# Load model.
multistate_model = loadrxnetwork(BNGNetwork(), "../Data/multistate.net");
@unpack A_P, A_unbound_P, A_bound_P, RLA_P = multistate_model.rn;
multistate_model_no_obs = loadrxnetwork(BNGNetwork(), "../Data/multistate_no_obs.net");

multistate_odeprob = ODEProblem(multistate_model.rn,Float64[],(0.,10.0),Float64[])
multistate_odeprob_no_obs = ODEProblem(multistate_model_no_obs.rn,Float64[],(0.,10.0),Float64[])

multistate_odeprob_jac = ODEProblem(convert(ODESystem,multistate_model.rn),Float64[],(0.,10.0),Float64[],jac=true,sparse=true)
multistate_odeprob_jac_no_obs = ODEProblem(convert(ODESystem,multistate_model_no_obs.rn),Float64[],(0.,10.0),Float64[],jac=true,sparse=true);

multistate_dprob = DiscreteProblem(multistate_model.rn,multistate_model.u₀,(0.,10.0),multistate_model.p); multistate_dprob = remake(multistate_dprob,u0=Int64.(multistate_dprob.u0));
multistate_dprob_no_obs = DiscreteProblem(multistate_model_no_obs.rn,multistate_model_no_obs.u₀,(0.,10.0),multistate_model_no_obs.p); multistate_dprob_no_obs = remake(multistate_dprob_no_obs,u0=Int64.(multistate_dprob_no_obs.u0));
# Out:
# Parsing parameters...done
# Creating parameters...done
# Parsing species...done
# Creating species...done
# Creating species and parameters for evaluating expressions...done
# Parsing and adding reactions...done
# Parsing groups...done
# Parsing parameters...done
# Creating parameters...done
# Parsing species...done
# Creating species...done
# Creating species and parameters for evaluating expressions...done
# Parsing and adding reactions...done
# Parsing groups...done

# %% [markdown]
# #### ODE Simulations

# %%
# Selects ODE solvers to try.
multistate_ode_solvers = [lsoda(), CVODE_BDF(), TRBDF2(), KenCarp4(), QNDF(), FBDF()];
multistate_ode_solvers_names = ["lsoda", "CVODE_BDF", "TRBDF2", "KenCarp4", "QNDF", "FBDF"];
multistate_jac_ode_solvers = [CVODE_BDF(linear_solver=:KLU), TRBDF2(linsolve=KLUFactorization()), KenCarp4(linsolve=KLUFactorization()), QNDF(linsolve=KLUFactorization()), FBDF(linsolve=KLUFactorization())];
multistate_jac_ode_solvers_names = ["CVODE_BDF", "TRBDF2", "KenCarp4", "QNDF", "FBDF"];

# %%
# Check ODE simulation outputs.
multistate_ode_sols = map((ode_solver,name) -> (println(name,":"); @time solve(multistate_odeprob,ode_solver;)), multistate_ode_solvers, multistate_ode_solvers_names);
multistate_ode_plots = map((sol,name) -> plot(sol,vars=[A_P, A_unbound_P, A_bound_P, RLA_P],xguide="Time",yguide="Concentration",title=name), multistate_ode_sols, multistate_ode_solvers_names);
plot(multistate_ode_plots...,layout=(1,length(multistate_ode_plots)),size=(length(multistate_ode_plots)*450,300))
# Out:
# lsoda:
#   0.000166 seconds (643 allocations: 44.734 KiB)
# CVODE_BDF:
#   0.000464 seconds (1.87 k allocations: 93.938 KiB)
# TRBDF2:
#   0.000284 seconds (358 allocations: 36.516 KiB)
# KenCarp4:
#   0.000366 seconds (421 allocations: 38.500 KiB)
# QNDF:
#   0.000393 seconds (742 allocations: 90.688 KiB)
# FBDF:
#   0.000531 seconds (719 allocations: 85.031 KiB)

# %%
# Check ODE simulation outputs for maximum length simulation.
multistate_ode_sols_long = map((ode_solver,name) -> (println(name,":"); @time solve(remake(multistate_odeprob,tspan=(0.0,100000.)),ode_solver;)), multistate_ode_solvers, multistate_ode_solvers_names);
multistate_ode_plots_long = map((sol,name) -> plot(sol,vars=[A_P, A_unbound_P, A_bound_P, RLA_P],xguide="Time",yguide="Concentration",title=name), multistate_ode_sols_long, multistate_ode_solvers_names);
plot(multistate_ode_plots_long...,layout=(1,length(multistate_ode_plots_long)),size=(length(multistate_ode_plots_long)*450,300))
# Out:
# lsoda:
#   0.000385 seconds (1.58 k allocations: 118.047 KiB)
# CVODE_BDF:
#   0.000571 seconds (2.19 k allocations: 108.594 KiB)
# TRBDF2:
#   0.000364 seconds (491 allocations: 52.688 KiB)
# KenCarp4:
#   0.000491 seconds (505 allocations: 48.094 KiB)
# QNDF:
#   0.000482 seconds (888 allocations: 106.938 KiB)
# FBDF:
#   0.000644 seconds (858 allocations: 100.500 KiB)

# %%
# Check ODE simulation times.
foreach((ode_solver,name) -> (println(name,":"); @time solve(multistate_odeprob_no_obs,ode_solver); println();), multistate_ode_solvers, multistate_ode_solvers_names);
# Out:
# lsoda:
#   0.000288 seconds (643 allocations: 44.734 KiB)
#
# CVODE_BDF:
#   0.000636 seconds (1.87 k allocations: 93.938 KiB)
#
# TRBDF2:
#   0.000331 seconds (358 allocations: 36.516 KiB)
#
# KenCarp4:
#   0.000408 seconds (421 allocations: 38.500 KiB)
#
# QNDF:
#   0.000413 seconds (742 allocations: 90.688 KiB)
#
# FBDF:
#   0.000545 seconds (719 allocations: 85.031 KiB)

# %%
# Check ODE simulation times (with jacobian).
foreach((ode_solver,name) -> (println(name,":"); @time solve(multistate_odeprob_jac_no_obs,ode_solver); println();), multistate_jac_ode_solvers, multistate_jac_ode_solvers_names);
# Out:
# CVODE_BDF:
#   0.000942 seconds (2.00 k allocations: 106.133 KiB)
#
# TRBDF2:
#   0.001244 seconds (7.20 k allocations: 637.680 KiB)
#
# KenCarp4:
#   0.001375 seconds (10.07 k allocations: 871.781 KiB)
#
# QNDF:
#   0.001151 seconds (8.30 k allocations: 756.164 KiB)
#
# FBDF:
#   0.001862 seconds (12.90 k allocations: 1.258 MiB)

# %%
# Benchmark ODE simulations.
lengs_multistate_ode = 10 .^(range(1,stop=5,length=5));
for (ode_solver,name) in zip(multistate_ode_solvers, multistate_ode_solvers_names)
    @time benchmarks = map(leng -> (op_interal = remake(multistate_odeprob_no_obs,tspan=(0.0,leng)); (@benchmark solve($op_interal,$ode_solver));), lengs_multistate_ode);
    json_serialize(benchmarks,lengs_multistate_ode,"catalyst_$(name)_multistate")
end

# %%
multistate_ode_benchmarks = map(name -> JSON.parsefile("../Benchmarking_results/Prototyping/catalyst_$(name)_multistate.json"), multistate_ode_solvers_names);
plot(); foreach((benchmark, name) -> plot!(benchmark["lengs"],benchmark["medians"],lw=7,la=0.8,label="$(name)"), multistate_ode_benchmarks, multistate_ode_solvers_names)
plot!(xlimit=(multistate_ode_benchmarks[1]["lengs"][1],multistate_ode_benchmarks[1]["lengs"][end]),ylimit=(1e-1,1.2*maximum(vcat(map(bm -> bm["medians"], multistate_ode_benchmarks)...))),yticks=[1e-1,1e0,1e1,1e2,1e3,1e4,1e5,1e6,1.2*maximum(vcat(map(bm -> bm["medians"], multistate_ode_benchmarks)...))],xaxis=:log,yaxis=:log,xguide="Simulation length",yguide="Simulation time (ms)",legend=:bottomright,legendfontsize=10)

# %% [markdown]
# #### Jump Simulations

# %%
# Selects Jump solvers to try.
multistate_jump_solvers = [Direct(), SortingDirect(), RSSA(), RSSACR()];
multistate_jump_solvers_names = ["Direct", "SortingDirect", "RSSA", "RSSACR"];
multistate_jump_problems = map(jump_solver -> JumpProblem(multistate_model.rn,multistate_dprob,jump_solver,save_positions=(false,false)), multistate_jump_solvers); 
multistate_jump_problems_no_obs = map(jump_solver -> JumpProblem(multistate_model.rn,multistate_dprob_no_obs,jump_solver,save_positions=(false,false)), multistate_jump_solvers);

# %%
# Check Jump simulation outputs.
multistate_jump_sols = map((jump_problem,name) -> (println(name,":"); @time solve(jump_problem,SSAStepper(),saveat=0.01);), multistate_jump_problems, multistate_jump_solvers_names);
multistate_jump_plots = map((sol,name) -> plot(sol,vars=[A_P, A_unbound_P, A_bound_P, RLA_P],xguide="Time",yguide="Copy numbers",title=name), multistate_jump_sols, multistate_jump_solvers_names);
plot(multistate_jump_plots...,layout=(1,length(multistate_jump_plots)),size=(length(multistate_jump_plots)*450,300))

# %%
# Check Jump simulation outputs for maximum length simulation.
multistate_jump_sols_long = map((jump_problem,name) -> (println(name,":"); @time solve(remake(jump_problem,tspan=(0.0,100000.)),SSAStepper(),saveat=100);), multistate_jump_problems, multistate_jump_solvers_names);
multistate_jump_plots_long = map((sol,name) -> plot(sol,vars=[A_P, A_unbound_P, A_bound_P, RLA_P],xguide="Time",yguide="Copy numbers",title=name), multistate_jump_sols_long, multistate_jump_solvers_names);
plot(multistate_jump_plots_long...,layout=(1,length(multistate_jump_plots_long)),size=(length(multistate_jump_plots_long)*450,300))

# %%
# Check Jump simulation times.
foreach((jump_problem,name) -> (println(name,":"); @time solve(jump_problem,SSAStepper()); println();), multistate_jump_problems_no_obs, multistate_jump_solvers_names);

# %%
# Benchmark Jump simulations.
lengs_multistate_jump = 10 .^(range(1,stop=5,length=5));
for (jump_problem,name) in zip(multistate_jump_problems_no_obs, multistate_jump_solvers_names)
    @time benchmarks = map(leng -> (jp_interal = remake(jump_problem,tspan=(0.0,leng)); (@benchmark solve($jp_interal,SSAStepper()));), lengs_multistate_jump);
    json_serialize(benchmarks,lengs_multistate_jump,"catalyst_$(name)_multistate")
end

# %%
multistate_jump_benchmarks = map(name -> JSON.parsefile("../Benchmarking_results/Prototyping/catalyst_$(name)_multistate.json"), multistate_jump_solvers_names);
plot(); foreach((benchmark, name) -> plot!(benchmark["lengs"],benchmark["medians"],lw=7,la=0.8,label="$(name)"), multistate_jump_benchmarks, multistate_jump_solvers_names)
plot!(xlimit=(multistate_jump_benchmarks[1]["lengs"][1],multistate_jump_benchmarks[1]["lengs"][end]),ylimit=(1e-1,1.2*maximum(vcat(map(bm -> bm["medians"], multistate_jump_benchmarks)...))),yticks=[1e-1,1e0,1e1,1e2,1e3,1e4,1e5,1e6,1.2*maximum(vcat(map(bm -> bm["medians"], multistate_jump_benchmarks)...))],xaxis=:log,yaxis=:log,xguide="Simulation length",yguide="Simulation time (ms)",legend=:bottomright,legendfontsize=10)

# %% [markdown]
# ### Multisite2

# %%
# Load model.
multisite2_model = loadrxnetwork(BNGNetwork(), "../Data/multisite2.net");
@unpack Rfree,Lfree,A1P = multisite2_model.rn;
multisite2_model_no_obs = loadrxnetwork(BNGNetwork(), "../Data/multisite2_no_obs.net");

multisite2_odeprob = ODEProblem(multisite2_model.rn,multisite2_model.u₀,(0.,10.0),multisite2_model.p)
multisite2_odeprob_no_obs = ODEProblem(multisite2_model_no_obs.rn,multisite2_model_no_obs.u₀,(0.,10.0),multisite2_model_no_obs.p)

multisite2_odeprob_jac = ODEProblem(convert(ODESystem,multisite2_model.rn),multisite2_model.u₀,(0.,10.0),multisite2_model.p,jac=true,sparse=true)
multisite2_odeprob_jac_no_obs = ODEProblem(convert(ODESystem,multisite2_model_no_obs.rn),multisite2_model_no_obs.u₀,(0.,10.0),multisite2_model_no_obs.p,jac=true,sparse=true);

multisite2_dprob = DiscreteProblem(multisite2_model.rn,multisite2_model.u₀,(0.,10.0),multisite2_model.p); multisite2_dprob = remake(multisite2_dprob,u0=Int64.(multisite2_dprob.u0));
multisite2_dprob_no_obs = DiscreteProblem(multisite2_model_no_obs.rn,multisite2_model_no_obs.u₀,(0.,10.0),multisite2_model_no_obs.p); multisite2_dprob_no_obs = remake(multisite2_dprob_no_obs,u0=Int64.(multisite2_dprob_no_obs.u0));
# Out:
# Parsing parameters...done
# Creating parameters...done
# Parsing species...done
# Creating species...done
# Creating species and parameters for evaluating expressions...done
# Parsing and adding reactions...done
# Parsing groups...done
# Parsing parameters...done
# Creating parameters...done
# Parsing species...done
# Creating species...done
# Creating species and parameters for evaluating expressions...done
# Parsing and adding reactions...done
# Parsing groups...done

# %% [markdown]
# #### ODE Simulations

# %%
# Selects ODE solvers to try.
multisite2_ode_solvers = [lsoda(), CVODE_BDF(), TRBDF2(autodiff=false), KenCarp4(), QNDF(), FBDF()];
multisite2_ode_solvers_names = ["lsoda", "CVODE_BDF", "TRBDF2", "KenCarp4", "QNDF", "FBDF"];
multisite2_jac_ode_solvers = [CVODE_BDF(linear_solver=:KLU), TRBDF2(linsolve=KLUFactorization()), KenCarp4(linsolve=KLUFactorization()), QNDF(linsolve=KLUFactorization()), FBDF(linsolve=KLUFactorization())];
multisite2_jac_ode_solvers_names = ["CVODE_BDF", "TRBDF2", "KenCarp4", "QNDF", "FBDF"];

# %%
# Check ODE simulation outputs.
multisite2_ode_sols = map((ode_solver,name) -> (println(name,":"); @time solve(multisite2_odeprob,ode_solver;)), multisite2_ode_solvers, multisite2_ode_solvers_names);
multisite2_ode_plots = map((sol,name) -> plot(sol,vars=[Rfree,Lfree,A1P],xguide="Time",yguide="Concentration",title=name), multisite2_ode_sols, multisite2_ode_solvers_names);
plot(multisite2_ode_plots...,layout=(1,length(multisite2_ode_plots)),size=(length(multisite2_ode_plots)*450,300))

# %%
# Check ODE simulation outputs for maximum length simulation.
multisite2_ode_sols_long = map((ode_solver,name) -> (println(name,":"); @time solve(remake(multisite2_odeprob,tspan=(0.0,10000.)),ode_solver;)), multisite2_ode_solvers, multisite2_ode_solvers_names);
multisite2_ode_plots_long = map((sol,name) -> plot(sol,vars=[Rfree,Lfree,A1P],xguide="Time",yguide="Concentration",title=name), multisite2_ode_sols_long, multisite2_ode_solvers_names);
plot(multisite2_ode_plots_long...,layout=(1,length(multisite2_ode_plots_long)),size=(length(multisite2_ode_plots_long)*450,300))

# %%
# Check ODE simulation times.
foreach((ode_solver,name) -> (println(name,":"); @time solve(multisite2_odeprob_no_obs,ode_solver); println();), multisite2_ode_solvers, multisite2_ode_solvers_names);

# %%
# Check ODE simulation times (with jacobian).
foreach((ode_solver,name) -> (println(name,":"); @time solve(multisite2_odeprob_jac_no_obs,ode_solver); println();), multisite2_jac_ode_solvers, multisite2_jac_ode_solvers_names);

# %%
# Benchmark ODE simulations.
lengs_multisite2_ode = 10 .^(range(1,stop=4,length=4));
for (ode_solver,name) in zip(multisite2_ode_solvers, multisite2_ode_solvers_names)
    @time benchmarks = map(leng -> (op_interal = remake(multisite2_odeprob_no_obs,tspan=(0.0,leng)); (@benchmark solve($op_interal,$ode_solver));), lengs_multisite2_ode);
    json_serialize(benchmarks,lengs_multisite2_ode,"catalyst_$(name)_multisite2")
end

# %%
multisite2_ode_benchmarks = map(ode_solver -> JSON.parsefile("../Benchmarking_results/Prototyping/catalyst_$(name)_multisite2.json"), multisite2_ode_solvers_names);
plot(); foreach((benchmark, ode_solver) -> plot!(benchmark["lengs"],benchmark["medians"],lw=7,la=0.8,label="$(name)"), multisite2_ode_benchmarks, multisite2_ode_solvers_names)
plot!(xlimit=(multisite2_ode_benchmarks[1]["lengs"][1],multisite2_ode_benchmarks[1]["lengs"][end]),ylimit=(1e-1,1.2*maximum(vcat(map(bm -> bm["medians"], multisite2_ode_benchmarks)...))),yticks=[1e-1,1e0,1e1,1e2,1e3,1e4,1e5,1e6,1.2*maximum(vcat(map(bm -> bm["medians"], multisite2_ode_benchmarks)...))],xaxis=:log,yaxis=:log,xguide="Simulation length",yguide="Simulation time (ms)",legend=:bottomright,legendfontsize=10)

# %% [markdown]
# #### Jump Simulations

# %%
# Selects Jump solvers to try.
multisite2_jump_solvers = [Direct(), SortingDirect(), RSSA(), RSSACR()];
multisite2_jump_solvers_names = ["Direct", "SortingDirect", "RSSA", "RSSACR"];
multisite2_jump_problems = map(jump_solver -> JumpProblem(multisite2_model.rn,multisite2_dprob,jump_solver,save_positions=(false,false)), multisite2_jump_solvers); 
multisite2_jump_problems_no_obs = map(jump_solver -> JumpProblem(multisite2_model.rn,multisite2_dprob_no_obs,jump_solver,save_positions=(false,false)), multisite2_jump_solvers);

# %%
# Check Jump simulation outputs.
multisite2_jump_sols = map((jump_problem,name) -> (println(name,":"); @time solve(jump_problem,SSAStepper(),saveat=0.01);), multisite2_jump_problems, multisite2_jump_solvers_names);
multisite2_jump_plots = map((sol,name) -> plot(sol,vars=[Rfree,Lfree,A1P],xguide="Time",yguide="Copy numbers",title=name), multisite2_jump_sols, multisite2_jump_solvers_names);
plot(multisite2_jump_plots...,layout=(1,length(multisite2_jump_plots)),size=(length(multisite2_jump_plots)*450,300))

# %%
# Check Jump simulation outputs for maximum length simulation.
multisite2_jump_sols_long = map((jump_problem,name) -> (println(name,":"); @time solve(remake(jump_problem,tspan=(0.0,10000.)),SSAStepper(),saveat=10.);), multisite2_jump_problems, multisite2_jump_solvers_names);
multisite2_jump_plots_long = map((sol,name) -> plot(sol,vars=[Rfree,Lfree,A1P],xguide="Time",yguide="Copy numbers",title=name), multisite2_jump_sols_long, multisite2_jump_solvers_names);
plot(multisite2_jump_plots_long...,layout=(1,length(multisite2_jump_plots_long)),size=(length(multisite2_jump_plots_long)*450,300))

# %%
# Check Jump simulation times.
foreach((jump_problem,jump_solver) -> (println(jump_solver,":"); @time solve(jump_problem,SSAStepper()); println();), multisite2_jump_problems_no_obs, multisite2_jump_solvers);

# %%
# Benchmark Jump simulations.
lengs_multisite2_jump = 10 .^(range(1,stop=4,length=4));
for (jump_problem,name) in zip(multisite2_jump_problems_no_obs, multisite2_jump_solvers_names)
    @time benchmarks = map(leng -> (jp_interal = remake(jump_problem,tspan=(0.0,leng)); (@benchmark solve($jp_interal,SSAStepper()));), lengs_multisite2_jump);
    json_serialize(benchmarks,lengs_multisite2_jump,"catalyst_$(name)_multisite2")
end

# %%
multisite2_jump_benchmarks = map(jump_solver -> JSON.parsefile("../Benchmarking_results/Prototyping/catalyst_$(name)_multisite2.json"), multisite2_jump_solvers_names);
plot(); foreach((benchmark, jump_solver) -> plot!(benchmark["lengs"],benchmark["medians"],lw=7,la=0.8,label="$(name)"), multisite2_jump_benchmarks, multisite2_jump_solvers_names)
plot!(xlimit=(multisite2_jump_benchmarks[1]["lengs"][1],multisite2_jump_benchmarks[1]["lengs"][end]),ylimit=(1e-1,1.2*maximum(vcat(map(bm -> bm["medians"], multisite2_jump_benchmarks)...))),yticks=[1e-1,1e0,1e1,1e2,1e3,1e4,1e5,1e6,1.2*maximum(vcat(map(bm -> bm["medians"], multisite2_jump_benchmarks)...))],xaxis=:log,yaxis=:log,xguide="Simulation length",yguide="Simulation time (ms)",legend=:bottomright,legendfontsize=10)

# %% [markdown]
# ### Egfr_net

# %%
# Load model.
egfr_net_model = loadrxnetwork(BNGNetwork(), "../Data/egfr_net.net");
@unpack Dimers,Sos_act,Y1068,Y1148,Shc_Grb,Shc_Grb_Sos,R_Grb2,R_Shc,R_ShcP,ShcP,R_G_S,R_S_G_S,Efgr_tot = egfr_net_model.rn;
egfr_net_model_no_obs = loadrxnetwork(BNGNetwork(), "../Data/egfr_net_no_obs.net");

egfr_net_odeprob = ODEProblem(egfr_net_model.rn,egfr_net_model.u₀,(0.,10.0),egfr_net_model.p)
egfr_net_odeprob_no_obs = ODEProblem(egfr_net_model_no_obs.rn,egfr_net_model_no_obs.u₀,(0.,10.0),egfr_net_model_no_obs.p)

egfr_net_odeprob_jac = ODEProblem(convert(ODESystem,egfr_net_model.rn),egfr_net_model.u₀,(0.,10.0),egfr_net_model.p,jac=true,sparse=true)
egfr_net_odeprob_jac_no_obs = ODEProblem(convert(ODESystem,egfr_net_model_no_obs.rn),egfr_net_model_no_obs.u₀,(0.,10.0),egfr_net_model_no_obs.p,jac=true,sparse=true);

egfr_net_dprob = DiscreteProblem(egfr_net_model.rn,egfr_net_model.u₀,(0.,10.0),egfr_net_model.p); egfr_net_dprob = remake(egfr_net_dprob,u0=Int64.(egfr_net_dprob.u0));
egfr_net_dprob_no_obs = DiscreteProblem(egfr_net_model_no_obs.rn,egfr_net_model_no_obs.u₀,(0.,10.0),egfr_net_model_no_obs.p); egfr_net_dprob_no_obs = remake(egfr_net_dprob_no_obs,u0=Int64.(egfr_net_dprob_no_obs.u0));
# Out:
# Parsing parameters...done
# Creating parameters...done
# Parsing species...done
# Creating species...done
# Creating species and parameters for evaluating expressions...done
# Parsing and adding reactions...done
# Parsing groups...done
# Parsing parameters...done
# Creating parameters...done
# Parsing species...done
# Creating species...done
# Creating species and parameters for evaluating expressions...done
# Parsing and adding reactions...done
# Parsing groups...done

# %% [markdown]
# #### ODE Simulations

# %%
# Selects ODE solvers to try.
egfr_net_ode_solvers = [lsoda(), CVODE_BDF(linear_solver=:LapackDense), TRBDF2(), KenCarp4(), QNDF(), FBDF()];
egfr_net_ode_solvers_names = ["lsoda", "CVODE_BDF", "TRBDF2", "KenCarp4", "QNDF", "FBDF"];
egfr_net_jac_ode_solvers = [CVODE_BDF(linear_solver=:KLU), TRBDF2(linsolve=KLUFactorization()), KenCarp4(linsolve=KLUFactorization()), QNDF(linsolve=KLUFactorization()), FBDF(linsolve=KLUFactorization())];
egfr_net_jac_ode_solvers_names = ["CVODE_BDF", "TRBDF2", "KenCarp4", "QNDF", "FBDF"];

# %%
# Check ODE simulation outputs.
egfr_net_ode_sols = map((ode_solver,name) -> (println(name,":"); @time solve(egfr_net_odeprob,ode_solver);), egfr_net_ode_solvers, egfr_net_ode_solvers_names);
egfr_net_ode_plots = map((sol,name) -> plot(sol,vars=[Dimers,Sos_act,Y1068,Y1148,Shc_Grb,Shc_Grb_Sos,R_Grb2,R_Shc,R_ShcP,ShcP,R_G_S,R_S_G_S,Efgr_tot],xguide="Time",yguide="Concentration",title=name), egfr_net_ode_sols, egfr_net_ode_solvers);
plot(egfr_net_ode_plots...,layout=(1,length(egfr_net_ode_plots)),size=(length(egfr_net_ode_plots)*450,300))
# Out:
# KenCarp4:
# 3583.347163 seconds (105.41 M allocations: 5.808 GiB, 0.08% gc time, 99.95% compilation time)
# QNDF:
#   7.169793 seconds (30.80 M allocations: 1.237 GiB, 4.72% gc time, 85.76% compilation time)
# FBDF:
#   6.625919 seconds (21.93 M allocations: 880.257 MiB, 4.03% gc time, 87.49% compilation time)

# %%
# Check ODE simulation outputs for maximum length simulation.
egfr_net_ode_sols_long = map((ode_solver,name) -> (println(name,":"); @time solve(remake(egfr_net_odeprob,tspan=(0.0,1000.)),ode_solver);), egfr_net_ode_solvers, egfr_net_ode_solvers_names);
egfr_net_ode_plots_long = map((sol,name) -> plot(sol,vars=[Dimers,Sos_act,Y1068,Y1148,Shc_Grb,Shc_Grb_Sos,R_Grb2,R_Shc,R_ShcP,ShcP,R_G_S,R_S_G_S,Efgr_tot],xguide="Time",yguide="Concentration",title=name), egfr_net_ode_sols_long, egfr_net_ode_solvers);
plot(egfr_net_ode_plots_long...,layout=(1,length(egfr_net_ode_plots_long)),size=(length(egfr_net_ode_plots_long)*450,300))

# %%
# Check ODE simulation times.
foreach((ode_solver,name) -> (println(name,":"); @time solve(egfr_net_odeprob_no_obs,ode_solver); println();), egfr_net_ode_solvers, egfr_net_ode_solvers_names);
# Out:
# lsoda:
# 325.566819 seconds (63.85 M allocations: 1.251 GiB, 0.11% gc time, 99.06% compilation time)
#
# CVODE_BDF:
#   3.185186 seconds (37.05 M allocations: 654.301 MiB, 4.01% gc time, 29.05% compilation time)
#
# TRBDF2:
# 3873.478567 seconds (74.49 M allocations: 4.069 GiB, 0.03% gc time, 99.98% compilation time)
#
# KenCarp4:
#   4.996662 seconds (30.35 M allocations: 1.437 GiB, 6.91% gc time, 68.67% compilation time)
#
# QNDF:
#   4.314133 seconds (22.97 M allocations: 899.038 MiB, 5.51% gc time, 78.33% compilation time)
#
# FBDF:
#   3.606538 seconds (18.06 M allocations: 681.064 MiB, 5.18% gc time, 78.64% compilation time)

# %%
# Check ODE simulation times (with jacobian).
foreach((ode_solver,name) -> (println(name,":"); @time solve(egfr_net_odeprob_jac_no_obs,ode_solver); println();), egfr_net_jac_ode_solvers, egfr_net_jac_ode_solvers_names);
# Out:
# CVODE_BDF:
# 190.362159 seconds (14.79 M allocations: 765.906 MiB, 0.21% gc time, 99.84% compilation time)
#
# TRBDF2:
#   4.922231 seconds (19.32 M allocations: 886.209 MiB, 15.63% gc time, 86.30% compilation time)
#
# KenCarp4:
#   4.134394 seconds (23.83 M allocations: 863.381 MiB, 4.73% gc time, 79.74% compilation time)
#
# QNDF:
#   3.987048 seconds (21.25 M allocations: 761.705 MiB, 4.39% gc time, 78.16% compilation time)
#
# FBDF:
#   3.396898 seconds (16.55 M allocations: 570.848 MiB, 3.98% gc time, 78.36% compilation time)

# %%
# Check ODE simulation times.
sols = map((ode_solver,name) -> (println(name,":"); @time solve(egfr_net_odeprob_no_obs,ode_solver);), egfr_net_ode_solvers[2:6], egfr_net_ode_solvers_names[2:6]);
# Out:
# CVODE_BDF:
#   2.552397 seconds (35.03 M allocations: 535.337 MiB, 7.14% gc time)
# TRBDF2:
#   1.111840 seconds (12.30 M allocations: 401.907 MiB, 8.65% gc time)
# KenCarp4:
#   1.887732 seconds (20.45 M allocations: 842.148 MiB, 10.18% gc time)
# QNDF:
#   1.161660 seconds (15.42 M allocations: 344.852 MiB, 4.12% gc time)
# FBDF:
#   0.987683 seconds (12.38 M allocations: 298.234 MiB, 9.86% gc time)

# %%
# Check ODE simulation times (with jacobian).
sols_jac = map((ode_solver,name) -> (println(name,":"); @time solve(egfr_net_odeprob_jac_no_obs,ode_solver);), egfr_net_jac_ode_solvers, egfr_net_jac_ode_solvers_names);
# Out:
# CVODE_BDF:
#   0.410562 seconds (4.19 M allocations: 66.959 MiB)
# TRBDF2:
#   0.643574 seconds (9.75 M allocations: 194.379 MiB, 6.34% gc time)
# KenCarp4:
#   0.838740 seconds (14.10 M allocations: 245.244 MiB, 4.52% gc time)
# QNDF:
#   0.825558 seconds (14.14 M allocations: 241.458 MiB, 5.13% gc time)
# FBDF:
#   0.676771 seconds (11.11 M allocations: 204.021 MiB, 5.96% gc time)

# %%
sols[1].destats # CVODE_BDF, no jac stuff.
# Out:
# DiffEqBase.DEStats
# Number of function 1 evaluations:                  94
# Number of function 2 evaluations:                  0
# Number of W matrix evaluations:                    24
# Number of linear solves:                           0
# Number of Jacobians created:                       2
# Number of nonlinear solver iterations:             92
# Number of nonlinear solver convergence failures:   0
# Number of rootfind condition calls:                0
# Number of accepted steps:                          82
# Number of rejected steps:                          1

# %%
sols[3].destats # KenCarp4, no jac stuff.
# Out:
# DiffEqBase.DEStats
# Number of function 1 evaluations:                  326
# Number of function 2 evaluations:                  0
# Number of W matrix evaluations:                    28
# Number of linear solves:                           344
# Number of Jacobians created:                       5
# Number of nonlinear solver iterations:             318
# Number of nonlinear solver convergence failures:   0
# Number of rootfind condition calls:                0
# Number of accepted steps:                          26
# Number of rejected steps:                          0

# %%
sols[5].destats # FBDF, no jac stuff.
# Out:
# DiffEqBase.DEStats
# Number of function 1 evaluations:                  256
# Number of function 2 evaluations:                  0
# Number of W matrix evaluations:                    32
# Number of linear solves:                           170
# Number of Jacobians created:                       1
# Number of nonlinear solver iterations:             170
# Number of nonlinear solver convergence failures:   0
# Number of rootfind condition calls:                0
# Number of accepted steps:                          81
# Number of rejected steps:                          1

# %%
sols_jac[1].destats # CVODE_BDF, jac stuff.
# Out:
# DiffEqBase.DEStats
# Number of function 1 evaluations:                  94
# Number of function 2 evaluations:                  0
# Number of W matrix evaluations:                    24
# Number of linear solves:                           0
# Number of Jacobians created:                       2
# Number of nonlinear solver iterations:             92
# Number of nonlinear solver convergence failures:   0
# Number of rootfind condition calls:                0
# Number of accepted steps:                          82
# Number of rejected steps:                          1

# %%
sols_jac[3].destats # KenCarp4, jac stuff.
# Out:
# DiffEqBase.DEStats
# Number of function 1 evaluations:                  321
# Number of function 2 evaluations:                  0
# Number of W matrix evaluations:                    28
# Number of linear solves:                           344
# Number of Jacobians created:                       5
# Number of nonlinear solver iterations:             318
# Number of nonlinear solver convergence failures:   0
# Number of rootfind condition calls:                0
# Number of accepted steps:                          26
# Number of rejected steps:                          0

# %%
sols_jac[5].destats # FBDF, jac stuff.
# Out:
# DiffEqBase.DEStats
# Number of function 1 evaluations:                  255
# Number of function 2 evaluations:                  0
# Number of W matrix evaluations:                    32
# Number of linear solves:                           170
# Number of Jacobians created:                       1
# Number of nonlinear solver iterations:             170
# Number of nonlinear solver convergence failures:   0
# Number of rootfind condition calls:                0
# Number of accepted steps:                          81
# Number of rejected steps:                          1

# %%
# Benchmark ODE simulations.
lengs_egfr_net_ode = 10 .^(range(1,stop=3,length=3));
for (ode_solver,name) in zip(egfr_net_ode_solvers, egfr_net_ode_solvers_names)
    @time benchmarks = map(leng -> (op_interal = remake(egfr_net_odeprob_no_obs,tspan=(0.0,leng)); (@benchmark solve($op_interal,$ode_solver));), lengs_egfr_net_ode);
    json_serialize(benchmarks,lengs_egfr_net_ode,"catalyst_$(name)_egfr_net")
end

# %%
egfr_net_ode_benchmarks = map(ode_solver -> JSON.parsefile("../Benchmarking_results/Prototyping/catalyst_$(name)_egfr_net.json"), egfr_net_ode_solvers_names);
plot(); foreach((benchmark, ode_solver) -> plot!(benchmark["lengs"],benchmark["medians"],lw=7,la=0.8,label="$(name)"), egfr_net_ode_benchmarks, egfr_net_ode_solvers_names)
plot!(xlimit=(egfr_net_ode_benchmarks[1]["lengs"][1],egfr_net_ode_benchmarks[1]["lengs"][end]),ylimit=(1e-1,1.2*maximum(vcat(map(bm -> bm["medians"], egfr_net_ode_benchmarks)...))),yticks=[1e-1,1e0,1e1,1e2,1e3,1e4,1e5,1e6,1.2*maximum(vcat(map(bm -> bm["medians"], egfr_net_ode_benchmarks)...))],xaxis=:log,yaxis=:log,xguide="Simulation length",yguide="Simulation time (ms)",legend=:bottomright,legendfontsize=10)

# %% [markdown]
# #### Jump Simulations

# %%
# Selects Jump solvers to try.
egfr_net_jump_solvers = [Direct(), SortingDirect(), RSSA(), RSSACR()];
egfr_net_jump_solvers_names = ["Direct", "SortingDirect", "RSSA", "RSSACR"];
egfr_net_jump_problems = map(jump_solver -> JumpProblem(egfr_net_model.rn,egfr_net_dprob,jump_solver,save_positions=(false,false)), egfr_net_jump_solvers); 
egfr_net_jump_problems_no_obs = map(jump_solver -> JumpProblem(egfr_net_model.rn,egfr_net_dprob_no_obs,jump_solver,save_positions=(false,false)), egfr_net_jump_solvers);

# %%
# Check Jump simulation outputs.
egfr_net_jump_sols = map((jump_problem,name) -> (println(name,":"); @time solve(jump_problem,SSAStepper(),saveat=0.01);), egfr_net_jump_problems, egfr_net_jump_solvers_names);
egfr_net_jump_plots = map((sol,name) -> plot(sol,vars=[Dimers,Sos_act,Y1068,Y1148,Shc_Grb,Shc_Grb_Sos,R_Grb2,R_Shc,R_ShcP,ShcP,R_G_S,R_S_G_S,Efgr_tot],xguide="Time",yguide="Copy numbers",title=name), egfr_net_jump_sols, egfr_net_jump_solvers_names);
plot(egfr_net_jump_plots...,layout=(1,length(egfr_net_jump_plots)),size=(length(egfr_net_jump_plots)*450,300))

# %%
# Check Jump simulation outputs for maximum length simulation.
egfr_net_jump_sols_long = map((jump_problem,name) -> (println(name,":"); @time solve(remake(jump_problem,tspan=(0.0,1000.)),SSAStepper(),saveat=1.);), egfr_net_jump_problems, egfr_net_jump_solvers_names);
egfr_net_jump_plots_long = map((sol,name) -> plot(sol,vars=[Dimers,Sos_act,Y1068,Y1148,Shc_Grb,Shc_Grb_Sos,R_Grb2,R_Shc,R_ShcP,ShcP,R_G_S,R_S_G_S,Efgr_tot],xguide="Time",yguide="Copy numbers",title=name), egfr_net_jump_sols_long, egfr_net_jump_solvers_names);
plot(egfr_net_jump_plots_long...,layout=(1,length(egfr_net_jump_plots_long)),size=(length(egfr_net_jump_plots_long)*450,300))

# %%
# Check Jump simulation times.
foreach((jump_problem,jump_solver) -> (println(jump_solver,":"); @time solve(jump_problem,SSAStepper()); println();), egfr_net_jump_problems, egfr_net_jump_solvers_names);

# %%
# Benchmark Jump simulations.
lengs_egfr_net_jump = 10 .^(range(1,stop=3,length=3));
for (jump_problem,name) in zip(egfr_net_jump_problems_no_obs, egfr_net_jump_solvers_names)
    @time benchmarks = map(leng -> (jp_interal = remake(jump_problem,tspan=(0.0,leng)); (@benchmark solve($jp_interal,SSAStepper()));), lengs_egfr_net_jump);
    json_serialize(benchmarks,lengs_egfr_net_jump,"catalyst_$(name)_egfr_net")
end

# %%
egfr_net_jump_benchmarks = map(jump_solver -> JSON.parsefile("../Benchmarking_results/Prototyping/catalyst_$(name)_egfr_net.json"), egfr_net_jump_solvers_names);
plot(); foreach((benchmark, jump_solver) -> plot!(benchmark["lengs"],benchmark["medians"],lw=7,la=0.8,label="$(name)"), egfr_net_jump_benchmarks, egfr_net_jump_solvers_names)
plot!(xlimit=(egfr_net_jump_benchmarks[1]["lengs"][1],egfr_net_jump_benchmarks[1]["lengs"][end]),ylimit=(1e-1,1.2*maximum(vcat(map(bm -> bm["medians"], egfr_net_jump_benchmarks)...))),yticks=[1e-1,1e0,1e1,1e2,1e3,1e4,1e5,1e6,1.2*maximum(vcat(map(bm -> bm["medians"], egfr_net_jump_benchmarks)...))],xaxis=:log,yaxis=:log,xguide="Simulation length",yguide="Simulation time (ms)",legend=:bottomright,legendfontsize=10)

# %% [markdown]
# ### BCR

# %%
# Load model.
BCR_model = loadrxnetwork(BNGNetwork(), "../Data/BCR.net");
@unpack Activated_Syk,Ig_alpha_P,Ig_alpha_PP,Ig_beta_PP,Activated_Lyn,Autoinhibited_Lyn,Activated_Fyn,Autoinhibited_Fyn,PAG1_Csk = BCR_model.rn;
BCR_model_no_obs = loadrxnetwork(BNGNetwork(), "../Data/BCR_no_obs.net");

BCR_odeprob = ODEProblem(BCR_model.rn,BCR_model.u₀,(0.,10.0),BCR_model.p)
BCR_odeprob_no_obs = ODEProblem(BCR_model_no_obs.rn,BCR_model_no_obs.u₀,(0.,10.0),BCR_model_no_obs.p)

BCR_odeprob_jac = ODEProblem(convert(ODESystem,BCR_model.rn),BCR_model.u₀,(0.,10.0),BCR_model.p,jac=true,sparse=true)
BCR_odeprob_jac_no_obs = ODEProblem(convert(ODESystem,BCR_model_no_obs.rn),BCR_model_no_obs.u₀,(0.,10.0),BCR_model_no_obs.p,jac=true,sparse=true);

# Change initial conditions to start at equilibrium.
BCR_jump_u₀ = JSON.parsefile("../Data/BCR_SSA_u0.json")

BCR_dprob = DiscreteProblem(BCR_model.rn,BCR_jump_u₀,(0.,10.0),BCR_model.p); BCR_dprob = remake(BCR_dprob,u0=Int64.(BCR_dprob.u0));
BCR_dprob_no_obs = DiscreteProblem(BCR_model_no_obs.rn,BCR_jump_u₀,(0.,10.0),BCR_model_no_obs.p); BCR_dprob_no_obs = remake(BCR_dprob_no_obs,u0=Int64.(BCR_dprob_no_obs.u0));
# Out:
# Parsing parameters...done
# Creating parameters...done
# Parsing species...done
# Creating species...done
# Creating species and parameters for evaluating expressions...done
# Parsing and adding reactions...done
# Parsing groups...done
# Parsing parameters...done
# Creating parameters...done
# Parsing species...done
# Creating species...done
# Creating species and parameters for evaluating expressions...done
# Parsing and adding reactions...done
# Parsing groups...done

# %% [markdown]
# #### ODE Simulations

# %%
# Selects ODE solvers to try.
BCR_ode_solvers = [lsoda(), CVODE_BDF(linear_solver=:LapackDense), TRBDF2(), KenCarp4(), QNDF(), FBDF()];
BCR_ode_solvers_names = ["lsoda", "CVODE_BDF", "TRBDF2", "KenCarp4", "QNDF", "FBDF"];
BCR_jac_ode_solvers = [CVODE_BDF(linear_solver=:KLU), TRBDF2(linsolve=KLUFactorization()), KenCarp4(linsolve=KLUFactorization()), QNDF(linsolve=KLUFactorization()), FBDF(linsolve=KLUFactorization())];
BCR_jac_ode_solvers_names = ["CVODE_BDF", "TRBDF2", "KenCarp4", "QNDF", "FBDF"];

# %%
# Check ODE simulation outputs.
BCR_ode_sols = map((ode_solver,name) -> (println(name,":"); @time solve(remake(BCR_odeprob,tspan=(0.0,1000.)),ode_solver;), BCR_ode_solvers, BCR_ode_solvers_names);
BCR_ode_plots = map((sol,name) -> plot(sol,vars=[Activated_Syk,Ig_alpha_P,Ig_alpha_PP,Ig_beta_PP,Activated_Lyn,Autoinhibited_Lyn,Activated_Fyn,Autoinhibited_Fyn,PAG1_Csk],xguide="Time",yguide="Concentration",title=name), BCR_ode_sols, BCR_ode_solvers_names);
plot(BCR_ode_plots...,layout=(1,length(BCR_ode_plots)),size=(length(BCR_ode_plots)*450,300))
# Out:
# syntax: incomplete: premature end of input
#
# Stacktrace:
#  [1] top-level scope
#    @ In[7]:2
#  [2] eval
#    @ ./boot.jl:373 [inlined]
#  [3] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base ./loading.jl:1196

# %%
# Check ODE simulation outputs for maximum length simulation.
BCR_ode_sols_long = map((ode_solver,name) -> (println(name,":"); @time solve(BCR_odeprob,ode_solver;), BCR_ode_solvers, BCR_ode_solvers_names);
BCR_ode_plots_long = map((sol,name) -> plot(sol,vars=[Activated_Syk,Ig_alpha_P,Ig_alpha_PP,Ig_beta_PP,Activated_Lyn,Autoinhibited_Lyn,Activated_Fyn,Autoinhibited_Fyn,PAG1_Csk],xguide="Time",yguide="Concentration",title=name), BCR_ode_sols_long, BCR_ode_solvers_names);
plot(BCR_ode_plots_long...,layout=(1,length(BCR_ode_plots_long)),size=(length(BCR_ode_plots_long)*450,300))

# %%
# Check ODE simulation times.
foreach((ode_solver,name) -> (println(name,":"); @time solve(BCR_odeprob_no_obs,ode_solver); println();), BCR_ode_solvers, BCR_ode_solvers_names);

# %%
# Check ODE simulation times (with jacobian).
foreach((ode_solver,name) -> (println(name,":"); @time solve(BCR_odeprob_jac_no_obs,ode_solver); println();), BCR_jac_ode_solvers, BCR_jac_ode_solvers_names);

# %%
# Benchmark ODE simulations.
lengs_BCR_ode = 10 .^(range(1,stop=3,length=3));
for (ode_solver,name) in zip(BCR_ode_solvers, BCR_ode_solvers_names)
    @time benchmarks = map(leng -> (op_interal = remake(BCR_odeprob_no_obs,tspan=(0.0,leng)); (@benchmark solve($op_interal,$ode_solver));), lengs_BCR_ode);
    json_serialize(benchmarks,lengs_BCR_ode,"catalyst_$(name)_BCR")
end

# %%
BCR_ode_benchmarks = map(ode_solver -> JSON.parsefile("../Benchmarking_results/Prototyping/catalyst_$(name)_BCR.json"), BCR_ode_solvers_names);
plot(); foreach((benchmark, ode_solver) -> plot!(benchmark["lengs"],benchmark["medians"],lw=7,la=0.8,label="$(name)"), BCR_ode_benchmarks, BCR_ode_solvers_names)
plot!(xlimit=(BCR_ode_benchmarks[1]["lengs"][1],BCR_ode_benchmarks[1]["lengs"][end]),ylimit=(1e-1,1.2*maximum(vcat(map(bm -> bm["medians"], BCR_ode_benchmarks)...))),yticks=[1e-1,1e0,1e1,1e2,1e3,1e4,1e5,1e6,1.2*maximum(vcat(map(bm -> bm["medians"], BCR_ode_benchmarks)...))],xaxis=:log,yaxis=:log,xguide="Simulation length",yguide="Simulation time (ms)",legend=:bottomright,legendfontsize=10)

# %% [markdown]
# #### Jump Simulations

# %%
# Selects Jump solvers to try.
BCR_jump_solvers = [Direct(), SortingDirect(), RSSA(), RSSACR()];
BCR_jump_solvers_names = ["Direct", "SortingDirect", "RSSA", "RSSACR"];
BCR_jump_problems = map(jump_solver -> JumpProblem(BCR_model.rn,BCR_dprob,jump_solver,save_positions=(false,false)), BCR_jump_solvers); 
BCR_jump_problems_no_obs = map(jump_solver -> JumpProblem(BCR_model.rn,BCR_dprob_no_obs,jump_solver,save_positions=(false,false)), BCR_jump_solvers);

# %%
@time sol = solve(remake(BCR_jump_problems[2];tspan=(0.,1000.)),SSAStepper(),saveat=1.);
plot(sol,vars=[Activated_Syk,Ig_alpha_P,Ig_alpha_PP,Ig_beta_PP,Activated_Lyn,Autoinhibited_Lyn,Activated_Fyn,Autoinhibited_Fyn,PAG1_Csk],xguide="Time",yguide="Concentration")

# %%
@time sol = solve(remake(BCR_jump_problems[2];tspan=(0.,10000.)),SSAStepper(),saveat=1.);
plot(sol,vars=[Activated_Syk,Ig_alpha_P,Ig_alpha_PP,Ig_beta_PP,Activated_Lyn,Autoinhibited_Lyn,Activated_Fyn,Autoinhibited_Fyn,PAG1_Csk],xguide="Time",yguide="Concentration")

# %%
@time sol = solve(remake(BCR_jump_problems[2];tspan=(0.,50000.)),SSAStepper(),saveat=1.);
plot(sol,vars=[Activated_Syk,Ig_alpha_P,Ig_alpha_PP,Ig_beta_PP,Activated_Lyn,Autoinhibited_Lyn,Activated_Fyn,Autoinhibited_Fyn,PAG1_Csk],xguide="Time",yguide="Concentration")

# %%
plot(sol,vars=[Activated_Syk],xguide="Time",yguide="Concentration")

# %%
# Check Jump simulation outputs.
BCR_jump_sols = map((jump_problem,name) -> (println(name,":"); @time solve(jump_problem,SSAStepper(),saveat=0.01);), BCR_jump_problems, BCR_jump_solvers_names);
BCR_jump_plots = map((sol,name) -> plot(sol,vars=[Activated_Syk,Ig_alpha_P,Ig_alpha_PP,Ig_beta_PP,Activated_Lyn,Autoinhibited_Lyn,Activated_Fyn,Autoinhibited_Fyn,PAG1_Csk],xguide="Time",yguide="Copy numbers",title=name), BCR_jump_sols, BCR_jump_solvers_names);
plot(BCR_jump_plots...,layout=(1,length(BCR_jump_plots)),size=(length(BCR_jump_plots)*450,300))

# %%
# Check Jump simulation times.
foreach((jump_problem,name) -> (println(name,":"); @time solve(jump_problem,SSAStepper()); println();), BCR_jump_problems_no_obs, BCR_jump_solvers_names);

# %%
# Benchmark Jump simulations.
lengs_BCR_jump = 10 .^(range(1,stop=5,length=5));
for (jump_problem,name) in zip(BCR_jump_problems_no_obs, BCR_jump_solvers_names)
    @time benchmarks = map(leng -> (jp_interal = remake(jump_problem,tspan=(0.0,leng)); (@benchmark solve($jp_interal,SSAStepper()));), lengs_BCR_jump);
    json_serialize(benchmarks,lengs_BCR_jump,"catalyst_$(name)_multistate")
end

# %%
multistate_jump_benchmarks = map(jump_solver -> JSON.parsefile("../Benchmarking_results/Prototyping/catalyst_$(name)_multistate.json"), BCR_jump_solvers_names);
plot(); foreach((benchmark, jump_solver) -> plot!(benchmark["lengs"],benchmark["medians"],lw=7,la=0.8,label="$(name)"), multistate_jump_benchmarks, BCR_jump_solvers_names)
plot!(xlimit=(multistate_jump_benchmarks[1]["lengs"][1],multistate_jump_benchmarks[1]["lengs"][end]),ylimit=(1e-1,1.2*maximum(vcat(map(bm -> bm["medians"], multistate_jump_benchmarks)...))),yticks=[1e-1,1e0,1e1,1e2,1e3,1e4,1e5,1e6,1.2*maximum(vcat(map(bm -> bm["medians"], multistate_jump_benchmarks)...))],xaxis=:log,yaxis=:log,xguide="Simulation length",yguide="Simulation time (ms)",legend=:bottomright,legendfontsize=10)

# %% [markdown]
# #### Extra, trying to fix how it is simualted.

# %%
BCR_SSA_model = loadrxnetwork(BNGNetwork(), "../Data/postequil_c3.net")
@unpack Activated_Syk = BCR_SSA_model.rn
BCR_jump_u₀ = JSON.parsefile("../Data/BCR_SSA_u0.json");
BCR_SSA_dprob = DiscreteProblem(convert(JumpSystem, BCR_SSA_model.rn), BCR_jump_u₀, (0.0,20000), []);

# %%
BCR_SSA_jump_solvers = [SortingDirect(), RSSA(), RSSACR()];
BCR_SSA_jump_solvers_names = ["SortingDirect", "RSSA", "RSSACR"];
BCR_SSA_jump_problems = map(jump_solver -> JumpProblem(convert(JumpSystem, BCR_SSA_model.rn), BCR_SSA_dprob, jump_solver, save_positions=(false,false)), BCR_SSA_jump_solvers);

# %%
# Check Jump simulation outputs.
BCR_SSA_jump_sols = map((jump_problem,name) -> (println(name,":"); @time solve(jump_problem,SSAStepper(), saveat=20000/5000);), BCR_SSA_jump_problems, BCR_SSA_jump_solvers_names);
BCR_SSA_jump_plots = map((sol,name) -> plot(sol,vars=[Activated_Syk],xguide="Time",yguide="Copy numbers",title=name), BCR_SSA_jump_sols, BCR_SSA_jump_solvers_names);
plot(BCR_SSA_jump_plots...,layout=(1,length(BCR_SSA_jump_plots)),size=(length(BCR_SSA_jump_plots)*450,300))

# %%
# Check Jump simulation times.
foreach((jump_problem,jump_solver) -> (println(jump_solver,":"); @time solve(jump_problem,SSAStepper(), saveat=20000/5000); println();), BCR_SSA_jump_problems, BCR_SSA_jump_solvers_names);

# %%
# Benchmark Jump simulations.
lengs_BCR_SSA_jump = 10 .^(range(4,stop=5,length=2));
for (jump_problem,name) in zip(BCR_SSA_jump_problems, BCR_SSA_jump_solvers_names)
    @time benchmarks = map(leng -> (jp_interal = remake(jump_problem,tspan=(0.0,leng)); (@benchmark solve($jp_interal,SSAStepper(), saveat=$leng/5000));), lengs_BCR_SSA_jump);
    json_serialize(benchmarks,lengs_BCR_SSA_jump,"catalyst_$(name)_BCR")
end

# %%
BCR_SSA_jump_benchmarks = map(jump_solver -> JSON.parsefile("../Benchmarking_results/Prototyping/catalyst_$(name)_BCR.json"), BCR_SSA_jump_solvers_names);
plot(); foreach((benchmark, jump_solver) -> plot!(benchmark["lengs"],benchmark["medians"],lw=7,la=0.8,label="$(name)"), BCR_SSA_jump_benchmarks, BCR_SSA_jump_solvers_names)
plot!(xlimit=(BCR_SSA_jump_benchmarks[1]["lengs"][1],BCR_SSA_jump_benchmarks[1]["lengs"][end]),ylimit=(1e-1,1.2*maximum(vcat(map(bm -> bm["medians"], BCR_SSA_jump_benchmarks)...))),yticks=[1e-1,1e0,1e1,1e2,1e3,1e4,1e5,1e6,1.2*maximum(vcat(map(bm -> bm["medians"], BCR_SSA_jump_benchmarks)...))],xaxis=:log,yaxis=:log,xguide="Simulation length",yguide="Simulation time (ms)",legend=:bottomright,legendfontsize=10)

# %% [markdown]
# ### Fceri_gamma2

# %%
# Load model.
fceri_gamma2_model = loadrxnetwork(BNGNetwork(), "../Data/fceri_gamma2.net");
@unpack LynFree,RecMon,RecPbeta,RecPgamma,RecSyk,RecSykPS = fceri_gamma2_model.rn;
fceri_gamma2_model_no_obs = loadrxnetwork(BNGNetwork(), "../Data/fceri_gamma2_no_obs.net");

fceri_gamma2_odeprob = ODEProblem(fceri_gamma2_model.rn,fceri_gamma2_model.u₀,(0.,10.0),fceri_gamma2_model.p)
fceri_gamma2_odeprob_no_obs = ODEProblem(fceri_gamma2_model_no_obs.rn,fceri_gamma2_model_no_obs.u₀,(0.,10.0),fceri_gamma2_model_no_obs.p)

fceri_gamma2_odeprob_jac = ODEProblem(convert(ODESystem,fceri_gamma2_model.rn),fceri_gamma2_model.u₀,(0.,10.0),fceri_gamma2_model.p,jac=true,sparse=true)
fceri_gamma2_odeprob_jac_no_obs = ODEProblem(convert(ODESystem,fceri_gamma2_model_no_obs.rn),fceri_gamma2_model_no_obs.u₀,(0.,10.0),fceri_gamma2_model_no_obs.p,jac=true,sparse=true);

fceri_gamma2_dprob = DiscreteProblem(fceri_gamma2_model.rn,fceri_gamma2_model.u₀,(0.,10.0),fceri_gamma2_model.p); fceri_gamma2_dprob = remake(fceri_gamma2_dprob,u0=Int64.(fceri_gamma2_dprob.u0));
fceri_gamma2_dprob_no_obs = DiscreteProblem(fceri_gamma2_model_no_obs.rn,fceri_gamma2_model_no_obs.u₀,(0.,10.0),fceri_gamma2_model_no_obs.p); fceri_gamma2_dprob_no_obs = remake(fceri_gamma2_dprob_no_obs,u0=Int64.(fceri_gamma2_dprob_no_obs.u0));

# %% [markdown]
# #### ODE Simulations

# %%
# Selects ODE solvers to try.
fceri_gamma2_ode_solvers = [lsoda(), CVODE_BDF(linear_solver=:LapackDense), TRBDF2(), KenCarp4(), QNDF(), FBDF()];
fceri_gamma2_ode_solvers_names = ["lsoda", "CVODE_BDF", "TRBDF2", "KenCarp4", "QNDF", "FBDF"];
fceri_gamma2_jac_ode_solvers = [CVODE_BDF(linear_solver=:KLU), TRBDF2(linsolve=KLUFactorization()), KenCarp4(linsolve=KLUFactorization()), QNDF(linsolve=KLUFactorization()), FBDF(linsolve=KLUFactorization())];
fceri_gamma2_jac_ode_solvers_names = ["CVODE_BDF", "TRBDF2", "KenCarp4", "QNDF", "FBDF"];

# %%
# Check ODE simulation outputs.
fceri_gamma2_ode_sols = map((ode_solver,name) -> (println(name,":"); @time solve(remake(fceri_gamma2_odeprob,tspan=(0.0,1000.)),ode_solver;), fceri_gamma2_ode_solvers, fceri_gamma2_ode_solvers_names);
fceri_gamma2_ode_plots = map((sol,name) -> plot(sol,vars=[LynFree,RecMon,RecPbeta,RecPgamma,RecSyk,RecSykPS],xguide="Time",yguide="Concentration",title=name), fceri_gamma2_ode_sols, fceri_gamma2_ode_solvers_names);
plot(fceri_gamma2_ode_plots...,layout=(1,length(fceri_gamma2_ode_plots)),size=(length(fceri_gamma2_ode_plots)*450,300))

# %%
# Check ODE simulation outputs for maximum length simulation.
fceri_gamma2_ode_sols_long = map((ode_solver,name) -> (println(name,":"); @time solve(fceri_gamma2_odeprob,ode_solver;), fceri_gamma2_ode_solvers, fceri_gamma2_ode_solvers_names);
fceri_gamma2_ode_plots_long = map((sol,name) -> plot(sol,vars=[LynFree,RecMon,RecPbeta,RecPgamma,RecSyk,RecSykPS],xguide="Time",yguide="Concentration",title=name), fceri_gamma2_ode_sols_long, fceri_gamma2_ode_solvers_names);
plot(fceri_gamma2_ode_plots_long...,layout=(1,length(fceri_gamma2_ode_plots_long)),size=(length(fceri_gamma2_ode_plots_long)*450,300))

# %%
# Check ODE simulation times.
foreach((ode_solver,name) -> (println(name,":"); @time solve(fceri_gamma2_odeprob_no_obs,ode_solver); println();), fceri_gamma2_ode_solvers, fceri_gamma2_ode_solvers_names);

# %%
# Check ODE simulation times (with jacobian).
foreach((ode_solver,name) -> (println(name,":"); @time solve(fceri_gamma2_odeprob_jac_no_obs,ode_solver); println();), fceri_gamma2_jac_ode_solvers[2:end], fceri_gamma2_ode_solvers_names[2:end]);

# %%
# Benchmark ODE simulations.
lengs_fceri_gamma2_ode = 10 .^(range(1,stop=3,length=3));
for (ode_solver,name) in zip(fceri_gamma2_ode_solvers, fceri_gamma2_ode_solvers_names)
    @time benchmarks = map(leng -> (op_interal = remake(fceri_gamma2_odeprob_no_obs,tspan=(0.0,leng)); (@benchmark solve($op_interal,$ode_solver));), lengs_fceri_gamma2_ode);
    json_serialize(benchmarks,lengs_fceri_gamma2_ode,"catalyst_$(name)_fceri_gamma2")
end

# %%
fceri_gamma2_ode_benchmarks = map(ode_solver -> JSON.parsefile("../Benchmarking_results/Prototyping/catalyst_$(name)_fceri_gamma2.json"), fceri_gamma2_ode_solvers_names);
plot(); foreach((benchmark, ode_solver) -> plot!(benchmark["lengs"],benchmark["medians"],lw=7,la=0.8,label="$(name)"), fceri_gamma2_ode_benchmarks, fceri_gamma2_ode_solvers_names)
plot!(xlimit=(fceri_gamma2_ode_benchmarks[1]["lengs"][1],fceri_gamma2_ode_benchmarks[1]["lengs"][end]),ylimit=(1e-1,1.2*maximum(vcat(map(bm -> bm["medians"], fceri_gamma2_ode_benchmarks)...))),yticks=[1e-1,1e0,1e1,1e2,1e3,1e4,1e5,1e6,1.2*maximum(vcat(map(bm -> bm["medians"], fceri_gamma2_ode_benchmarks)...))],xaxis=:log,yaxis=:log,xguide="Simulation length",yguide="Simulation time (ms)",legend=:bottomright,legendfontsize=10)

# %% [markdown]
# #### Jump Simulations

# %%
# Selects Jump solvers to try.
fceri_gamma2_jump_solvers = [Direct(), SortingDirect(), RSSA(), RSSACR()];
fceri_gamma2_jump_solvers_names = ["Direct", "SortingDirect", "RSSA", "RSSACR"];
fceri_gamma2_jump_problems = map(jump_solver -> JumpProblem(fceri_gamma2_model.rn,fceri_gamma2_dprob,jump_solver,save_positions=(false,false)), fceri_gamma2_jump_solvers); 
fceri_gamma2_jump_problems_no_obs = map(jump_solver -> JumpProblem(fceri_gamma2_model.rn,fceri_gamma2_dprob_no_obs,jump_solver,save_positions=(false,false)), fceri_gamma2_jump_solvers);

# %%
# Check Jump simulation outputs.
fceri_gamma2_jump_sols = map((jump_problem,name) -> (println(name,":"); @time solve(jump_problem,SSAStepper(),saveat=0.01);), fceri_gamma2_jump_problems, fceri_gamma2_jump_solvers_names);
fceri_gamma2_jump_plots = map((sol,name) -> plot(sol,vars=[LynFree,RecMon,RecPbeta,RecPgamma,RecSyk,RecSykPS],xguide="Time",yguide="Copy numbers",title=name), fceri_gamma2_jump_sols, fceri_gamma2_jump_solvers_names);
plot(fceri_gamma2_jump_plots...,layout=(1,length(fceri_gamma2_jump_plots)),size=(length(fceri_gamma2_jump_plots)*450,300))

# %%
# Check Jump simulation outputs for maximum length simulation.
fceri_gamma2_jump_sols_long = map((jump_problem,name) -> (println(name,":"); @time solve(remake(jump_problem,tspan=(0.0,1000.)),SSAStepper(),saveat=1.);), fceri_gamma2_jump_problems, fceri_gamma2_jump_solvers_names);
fceri_gamma2_jump_plots_long = map((sol,name) -> plot(sol,vars=[LynFree,RecMon,RecPbeta,RecPgamma,RecSyk,RecSykPS],xguide="Time",yguide="Copy numbers",title=name), fceri_gamma2_jump_sols, fceri_gamma2_jump_solvers_names);
plot(fceri_gamma2_jump_plots_long...,layout=(1,length(fceri_gamma2_jump_plots)),size=(length(fceri_gamma2_jump_plots)*450,300))

# %%
# Check Jump simulation times.
foreach((jump_problem,name) -> (println(name,":"); @time solve(jump_problem,SSAStepper()); println();), fceri_gamma2_jump_problems_no_obs, fceri_gamma2_jump_solvers_names);

# %%
# Benchmark Jump simulations.
lengs_fceri_gamma2_jump = 10 .^(range(1,stop=3,length=3));
for (jump_problem,name) in zip(fceri_gamma2_jump_problems_no_obs, fceri_gamma2_jump_solvers_names)
    @time benchmarks = map(leng -> (jp_interal = remake(jump_problem,tspan=(0.0,leng)); (@benchmark solve($jp_interal,SSAStepper()));), lengs_fceri_gamma2_jump);
    json_serialize(benchmarks,lengs_fceri_gamma2_jump,"catalyst_$(name)_fceri_gamma2")
end

# %%
fceri_gamma2_jump_benchmarks = map(jump_solver -> JSON.parsefile("../Benchmarking_results/Prototyping/catalyst_$(name)_fceri_gamma2.json"), fceri_gamma2_jump_solvers_names);
plot(); foreach((benchmark, jump_solver) -> plot!(benchmark["lengs"],benchmark["medians"],lw=7,la=0.8,label="$(name)"), fceri_gamma2_jump_benchmarks, fceri_gamma2_jump_solvers_names)
plot!(xlimit=(fceri_gamma2_jump_benchmarks[1]["lengs"][1],fceri_gamma2_jump_benchmarks[1]["lengs"][end]),ylimit=(1e-1,1.2*maximum(vcat(map(bm -> bm["medians"], fceri_gamma2_jump_benchmarks)...))),yticks=[1e-1,1e0,1e1,1e2,1e3,1e4,1e5,1e6,1.2*maximum(vcat(map(bm -> bm["medians"], fceri_gamma2_jump_benchmarks)...))],xaxis=:log,yaxis=:log,xguide="Simulation length",yguide="Simulation time (ms)",legend=:bottomright,legendfontsize=10)
